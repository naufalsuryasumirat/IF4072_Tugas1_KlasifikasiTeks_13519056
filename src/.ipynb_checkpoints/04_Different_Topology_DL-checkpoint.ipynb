# %% [markdown]
# # Authored By Leonardus James Wang

# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import pandas as pd

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import metrics

from sklearn.model_selection import train_test_split

import numpy as np

def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

# %% [markdown]
# ## Check Path and Load Data

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %%
path = '../data/'

dataset_dir = os.path.dirname(path)

# %%
os.listdir(dataset_dir)
# Out:
# ['check.py', 'dev.csv', 'labels.txt', 'test.csv', 'train.csv']

# %% [markdown]
# ## Text Preprocessing

# %%
train_dir = os.path.join(dataset_dir, 'train.csv')
validate_dir = os.path.join(dataset_dir, 'test.csv')

df = pd.read_csv(train_dir)
df = df.drop(df.columns[[0]],axis = 1)
#Remove Numbers
df['text_a'] = df['text_a'].str.replace('\d+', '', regex=True)

df_train, df_test = train_test_split(df, test_size=0.2)

df_validate = pd.read_csv(validate_dir)
#Remove Numbers
df_validate['text_a'] = df_validate['text_a'].str.replace('\d+', '', regex=True)

# %%
# Make sure there is no numbers

df_validate
# Out:
#                                                  text_a label
# 0                               jek dajal ga depok bang    no
# 1     detikcom untung depok masuk wilayah nya ridwan...    no
# 2     df dom jakarta depok yg gunain vc cabang nya c...    no
# 3                                      yourrl depok jkt    no
# 4     doakan indonesia selamat virus corona pkb depo...   yes
# ...                                                 ...   ...
# 2795  ku tenang bae ku sih ya corona nya ga depok ku...    no
# 2796  guru hati hati ya virus corona uda indonesia t...   yes
# 2797   terawan menyebut virus corona indonesia terde...   yes
# 2798        realffk buhari can t pronounce corona virus    no
# 2799  hadapi wabah corona pemuda muhammadiyah pemeri...   yes
#
# [2800 rows x 2 columns]

# %%
print("Check for None values")
print(f"Train: {df_train.isna().sum().sum()}")
print(f"Test: {df_test.isna().sum().sum()}")
print(f"Validate: {df_validate.isna().sum().sum()}")
print()
print("Check for Empty String")
print(f"Train: {(df_train['text_a'].values == '').sum()}")
print(f"Test: {(df_test['text_a'].values == '').sum()}")
print(f"Validate: {(df_validate['text_a'].values == '').sum()}")
print()
print("Check for missing labels")
print(f"Train: {df_train['label'].map({'no': 0.0, 'yes': 1.0}).isna().sum()}")
print(f"Test: {df_test['label'].map({'no': 0.0, 'yes': 1.0}).isna().sum()}")
print(f"Validate: {df_validate['label'].map({'no': 0.0, 'yes': 1.0}).isna().sum()}")
# Out:
# Check for None values
# Train: 0
# Test: 0
# Validate: 0
#
# Check for Empty String
# Train: 0
# Test: 0
# Validate: 0
#
# Check for missing labels
# Train: 0
# Test: 0
# Validate: 0

# %%
# Formatting from pandas to tensor object and mapping yes and no to 1.0 and 0.0

train_dataset = tf.data.Dataset.from_tensor_slices((df_train['text_a'], df_train['label'].map({'no': 0.0, 'yes': 1.0})))
test_dataset = tf.data.Dataset.from_tensor_slices((df_test['text_a'], df_test['label'].map({'no': 0.0, 'yes': 1.0})))
validate_dataset = tf.data.Dataset.from_tensor_slices((df_validate['text_a'], df_validate['label'].map({'no': 0.0, 'yes': 1.0})))
print(train_dataset.element_spec)
print(test_dataset.element_spec)
print(validate_dataset.element_spec)
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.float64, name=None))
# (TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.float64, name=None))
# (TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.float64, name=None))

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 64
train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
validate_dataset = validate_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

for example, label in train_dataset.take(1):
  print('texts: ', example.numpy()[:3])
  print()
  print('labels: ', label.numpy()[:3])
# Out:
# texts:  [b'firza utama ecstaciid emang udah gamau ngobrol orang depok takut cuek'
#  b'babinkamtimas brig subarkah efendi melaksanakan sosialisasi himbauan wajib masker sosialisasi maklumat kapolri larangan berkumpul kongko yg g pnting berkerumun memutus mata rantai wabah covid '
#  b'allunamaharani emang proaktif gejala corona common cold']
#
# labels:  [0. 1. 0.]

# %% [markdown]
# ## Text Vectorazation

# %%
# Do Text Vectorazation 

VOCAB_SIZE = 1000
encoder = tf.keras.layers.TextVectorization(
    max_tokens=VOCAB_SIZE)

# encoder.adapt(train_dataset.map(lambda text, label: text))
encoder.adapt(tf.data.Dataset.from_tensor_slices(df['text_a']))
for text in tf.data.Dataset.from_tensor_slices(df['text_a']).take(5):
    print('texts: ', text.numpy())
# Out:
# texts:  b'betewe buka twitter cuman ngetweet liat home berita corona panik kepikiran ndamau buka home yg aware aja i ll stay at home nda rumah kalo nda penting banget'
# texts:  b'mas piyuuu mugo corona tuh mulut tersumpal ma corona'
# texts:  b'ess gini buka informasi sejelas nya identitas daerah penderita terjangkit infokan masyarakat mengisolasi nya kontak langsung penderita positif corona ditutup tutupi'
# texts:  b'neng solo wes ono terduga corona cobo neng ati mu neng conora'
# texts:  b'midiahn nii akun gak takut takut nya isu corona wkwkwkw'

# %% [markdown]
# ## Make Model

# %%
model = tf.keras.Sequential([
    encoder,
    tf.keras.layers.Embedding(
        input_dim=len(encoder.get_vocabulary()),
        output_dim=64,
        mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

simpleRNNModel = tf.keras.Sequential([
    encoder,
    tf.keras.layers.Embedding(
        input_dim=len(encoder.get_vocabulary()),
        output_dim=64,
        mask_zero=True),
    tf.keras.layers.SimpleRNN(64),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# noRNNModel = tf.keras.Sequential([
#     encoder,
#     tf.keras.layers.Embedding(
#         input_dim=len(encoder.get_vocabulary()),
#         output_dim=64,
#         mask_zero=True),
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.Dense(32, activation='relu'),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])

doubleRNNModel = tf.keras.Sequential([
    encoder,
    tf.keras.layers.Embedding(
        input_dim=len(encoder.get_vocabulary()),
        output_dim=64,
        mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
#Check if padding of words contribute anything to the predictions 
#Check without padding

sample_text = df_validate["text_a"][4]
predictions = model.predict(np.array([sample_text]))
print(predictions)

predictions = simpleRNNModel.predict(np.array([sample_text]))
print(predictions)

# predictions = noRNNModel.predict(np.array([sample_text]))
# print(predictions)

predictions = doubleRNNModel.predict(np.array([sample_text]))
print(predictions)
# Out:
# 1/1 [==============================] - 5s 5s/step
# [[-0.0038066]]
# 1/1 [==============================] - 0s 314ms/step
# [[0.09047672]]
# 1/1 [==============================] - 9s 9s/step
# [[0.00851678]]

# %%
#Check with padding

padding = "the " * 2000
predictions = model.predict(np.array([sample_text, padding]))
print(predictions[0])

predictions = simpleRNNModel.predict(np.array([sample_text, padding]))
print(predictions[0])

# predictions = noRNNModel.predict(np.array([sample_text, padding]))
# print(predictions[0])

predictions = doubleRNNModel.predict(np.array([sample_text, padding]))
print(predictions[0])
# Out:
# 1/1 [==============================] - 0s 134ms/step
# [-0.00380659]
# 1/1 [==============================] - 0s 77ms/step
# [0.09047674]
# 1/1 [==============================] - 0s 249ms/step
# [0.00851678]

# %% [markdown]
# ## Compile and Train Model

# %%
#Compile model
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=[
                'accuracy',
                metrics.Recall(),
                metrics.Precision()
              ])

simpleRNNModel.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=[
                'accuracy',
                metrics.Recall(),
                metrics.Precision()
              ])

# noRNNModel.compile(loss=tf.keras.losses.BinaryCrossentropy(),
#               optimizer=tf.keras.optimizers.Adam(1e-4),
#               metrics=[
#                 'accuracy',
#                 metrics.Recall(),
#                 metrics.Precision()
#               ])

doubleRNNModel.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=[
                'accuracy',
                metrics.Recall(),
                metrics.Precision()
              ])

# %%
history = model.fit(train_dataset, epochs=10,
                    validation_data=test_dataset,
                    validation_steps=30)
# Out:
# Epoch 1/10
# 270/270 [==============================] - 21s 56ms/step - loss: 0.5846 - accuracy: 0.7193 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 0.5159 - val_accuracy: 0.7073 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 2/10
# 270/270 [==============================] - 14s 51ms/step - loss: 0.4225 - accuracy: 0.7867 - recall: 0.3173 - precision: 0.8041 - val_loss: 0.3901 - val_accuracy: 0.8182 - val_recall: 0.5053 - val_precision: 0.8000
# Epoch 3/10
# 270/270 [==============================] - 14s 51ms/step - loss: 0.3577 - accuracy: 0.8414 - recall: 0.5668 - precision: 0.8114 - val_loss: 0.3631 - val_accuracy: 0.8432 - val_recall: 0.5890 - val_precision: 0.8254
# Epoch 4/10
# 270/270 [==============================] - 14s 51ms/step - loss: 0.3349 - accuracy: 0.8531 - recall: 0.6134 - precision: 0.8178 - val_loss: 0.3513 - val_accuracy: 0.8547 - val_recall: 0.6370 - val_precision: 0.8268
# Epoch 5/10
# 270/270 [==============================] - 14s 54ms/step - loss: 0.3206 - accuracy: 0.8595 - recall: 0.6297 - precision: 0.8285 - val_loss: 0.3453 - val_accuracy: 0.8557 - val_recall: 0.6352 - val_precision: 0.8322
# Epoch 6/10
# 270/270 [==============================] - 14s 53ms/step - loss: 0.3112 - accuracy: 0.8621 - recall: 0.6381 - precision: 0.8313 - val_loss: 0.3411 - val_accuracy: 0.8573 - val_recall: 0.6388 - val_precision: 0.8349
# Epoch 7/10
# 270/270 [==============================] - 15s 54ms/step - loss: 0.3034 - accuracy: 0.8650 - recall: 0.6462 - precision: 0.8355 - val_loss: 0.3469 - val_accuracy: 0.8557 - val_recall: 0.6050 - val_precision: 0.8608
# Epoch 8/10
# 270/270 [==============================] - 15s 54ms/step - loss: 0.2975 - accuracy: 0.8672 - recall: 0.6540 - precision: 0.8374 - val_loss: 0.3423 - val_accuracy: 0.8604 - val_recall: 0.6423 - val_precision: 0.8435
# Epoch 9/10
# 270/270 [==============================] - 16s 57ms/step - loss: 0.2924 - accuracy: 0.8720 - recall: 0.6707 - precision: 0.8412 - val_loss: 0.3420 - val_accuracy: 0.8646 - val_recall: 0.6619 - val_precision: 0.8416
# Epoch 10/10
# 270/270 [==============================] - 15s 55ms/step - loss: 0.2879 - accuracy: 0.8738 - recall: 0.6730 - precision: 0.8460 - val_loss: 0.3430 - val_accuracy: 0.8641 - val_recall: 0.6690 - val_precision: 0.8337

# %%
simpleRNNHistory = simpleRNNModel.fit(train_dataset, epochs=10,
                    validation_data=test_dataset,
                    validation_steps=30)
# Out:
# Epoch 1/10
# 270/270 [==============================] - 5s 14ms/step - loss: 0.5717 - accuracy: 0.7260 - recall_1: 0.0332 - precision_1: 0.7816 - val_loss: 0.4611 - val_accuracy: 0.7786 - val_recall_1: 0.3505 - val_precision_1: 0.7665
# Epoch 2/10
# 270/270 [==============================] - 4s 13ms/step - loss: 0.4109 - accuracy: 0.8107 - recall_1: 0.4381 - precision_1: 0.7956 - val_loss: 0.3918 - val_accuracy: 0.8245 - val_recall_1: 0.4840 - val_precision_1: 0.8527
# Epoch 3/10
# 270/270 [==============================] - 4s 13ms/step - loss: 0.3608 - accuracy: 0.8413 - recall_1: 0.5588 - precision_1: 0.8182 - val_loss: 0.3683 - val_accuracy: 0.8516 - val_recall_1: 0.5961 - val_precision_1: 0.8524
# Epoch 4/10
# 270/270 [==============================] - 4s 13ms/step - loss: 0.3323 - accuracy: 0.8568 - recall_1: 0.6161 - precision_1: 0.8298 - val_loss: 0.3567 - val_accuracy: 0.8526 - val_recall_1: 0.6121 - val_precision_1: 0.8411
# Epoch 5/10
# 270/270 [==============================] - 4s 13ms/step - loss: 0.3147 - accuracy: 0.8644 - recall_1: 0.6416 - precision_1: 0.8372 - val_loss: 0.3586 - val_accuracy: 0.8495 - val_recall_1: 0.6050 - val_precision_1: 0.8354
# Epoch 6/10
# 270/270 [==============================] - 4s 14ms/step - loss: 0.3003 - accuracy: 0.8701 - recall_1: 0.6563 - precision_1: 0.8463 - val_loss: 0.3559 - val_accuracy: 0.8495 - val_recall_1: 0.6477 - val_precision_1: 0.8000
# Epoch 7/10
# 270/270 [==============================] - 4s 14ms/step - loss: 0.2914 - accuracy: 0.8753 - recall_1: 0.6765 - precision_1: 0.8485 - val_loss: 0.3595 - val_accuracy: 0.8531 - val_recall_1: 0.6423 - val_precision_1: 0.8167
# Epoch 8/10
# 270/270 [==============================] - 4s 14ms/step - loss: 0.2775 - accuracy: 0.8814 - recall_1: 0.6942 - precision_1: 0.8561 - val_loss: 0.3639 - val_accuracy: 0.8490 - val_recall_1: 0.6228 - val_precision_1: 0.8178
# Epoch 9/10
# 270/270 [==============================] - 4s 13ms/step - loss: 0.2651 - accuracy: 0.8867 - recall_1: 0.7078 - precision_1: 0.8639 - val_loss: 0.3614 - val_accuracy: 0.8526 - val_recall_1: 0.6530 - val_precision_1: 0.8066
# Epoch 10/10
# 270/270 [==============================] - 4s 13ms/step - loss: 0.2534 - accuracy: 0.8922 - recall_1: 0.7252 - precision_1: 0.8693 - val_loss: 0.3644 - val_accuracy: 0.8490 - val_recall_1: 0.6762 - val_precision_1: 0.7787

# %%
# noRNNHistory = noRNNModel.fit(train_dataset, epochs=10,
#                     validation_data=test_dataset,
#                     validation_steps=30)

# %%
doubleRNNHistory = doubleRNNModel.fit(train_dataset, epochs=10,
                    validation_data=test_dataset,
                    validation_steps=30)
# Out:
# Epoch 1/10
# 270/270 [==============================] - 38s 101ms/step - loss: 0.7028 - accuracy: 0.7183 - recall_2: 2.0619e-04 - precision_2: 0.0526 - val_loss: 0.5966 - val_accuracy: 0.7073 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 2/10
# 270/270 [==============================] - 24s 88ms/step - loss: 0.5003 - accuracy: 0.7641 - recall_2: 0.2151 - precision_2: 0.7950 - val_loss: 0.4282 - val_accuracy: 0.7911 - val_recall_2: 0.3772 - val_precision_2: 0.8061
# Epoch 3/10
# 270/270 [==============================] - 25s 91ms/step - loss: 0.4144 - accuracy: 0.8240 - recall_2: 0.4992 - precision_2: 0.7982 - val_loss: 0.4099 - val_accuracy: 0.8224 - val_recall_2: 0.5214 - val_precision_2: 0.8027
# Epoch 4/10
# 270/270 [==============================] - 25s 92ms/step - loss: 0.3842 - accuracy: 0.8293 - recall_2: 0.5043 - precision_2: 0.8175 - val_loss: 0.4148 - val_accuracy: 0.8411 - val_recall_2: 0.5872 - val_precision_2: 0.8189
# Epoch 5/10
# 270/270 [==============================] - 24s 89ms/step - loss: 0.3597 - accuracy: 0.8442 - recall_2: 0.5763 - precision_2: 0.8144 - val_loss: 0.4051 - val_accuracy: 0.8448 - val_recall_2: 0.6157 - val_precision_2: 0.8084
# Epoch 6/10
# 270/270 [==============================] - 24s 91ms/step - loss: 0.3499 - accuracy: 0.8510 - recall_2: 0.6148 - precision_2: 0.8083 - val_loss: 0.4176 - val_accuracy: 0.8484 - val_recall_2: 0.6228 - val_precision_2: 0.8159
# Epoch 7/10
# 270/270 [==============================] - 25s 88ms/step - loss: 0.3421 - accuracy: 0.8572 - recall_2: 0.6260 - precision_2: 0.8228 - val_loss: 0.4138 - val_accuracy: 0.8490 - val_recall_2: 0.6157 - val_precision_2: 0.8238
# Epoch 8/10
# 270/270 [==============================] - 25s 93ms/step - loss: 0.3333 - accuracy: 0.8604 - recall_2: 0.6536 - precision_2: 0.8124 - val_loss: 0.4293 - val_accuracy: 0.8495 - val_recall_2: 0.6157 - val_precision_2: 0.8258
# Epoch 9/10
# 270/270 [==============================] - 25s 94ms/step - loss: 0.3278 - accuracy: 0.8633 - recall_2: 0.6594 - precision_2: 0.8181 - val_loss: 0.4564 - val_accuracy: 0.8521 - val_recall_2: 0.6335 - val_precision_2: 0.8203
# Epoch 10/10
# 270/270 [==============================] - 27s 98ms/step - loss: 0.3219 - accuracy: 0.8653 - recall_2: 0.6674 - precision_2: 0.8193 - val_loss: 0.4763 - val_accuracy: 0.8552 - val_recall_2: 0.6690 - val_precision_2: 0.8034

# %% [markdown]
# ## Result

# %%
print("Single LSTM Model")
train_loss, train_acc, train_recall, train_precision = model.evaluate(train_dataset)

print('Train Loss:', train_loss)
print('Train Accuracy:', train_acc)
print('Train Recall:', train_recall)
print('Train Precision:', train_precision)

test_loss, test_acc, test_recall, test_precision = model.evaluate(test_dataset)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Test Recall:', test_recall)
print('Test Precision:', test_precision)


validate_loss, validate_acc, validate_recall, validate_precision = model.evaluate(validate_dataset)

print('Validate Loss:', validate_loss)
print('Validate Accuracy:', validate_acc)
print('Validate Recall:', validate_recall)
print('Validate Precision:', validate_precision)

print("\nSimpleRNN Model")
train_loss, train_acc, train_recall, train_precision = simpleRNNModel.evaluate(train_dataset)

print('Train Loss:', train_loss)
print('Train Accuracy:', train_acc)
print('Train Recall:', train_recall)
print('Train Precision:', train_precision)

test_loss, test_acc, test_recall, test_precision = simpleRNNModel.evaluate(test_dataset)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Test Recall:', test_recall)
print('Test Precision:', test_precision)


validate_loss, validate_acc, validate_recall, validate_precision = simpleRNNModel.evaluate(validate_dataset)

print('Validate Loss:', validate_loss)
print('Validate Accuracy:', validate_acc)
print('Validate Recall:', validate_recall)
print('Validate Precision:', validate_precision)


print("\nDoubleLSTM Model")
train_loss, train_acc, train_recall, train_precision = doubleRNNModel.evaluate(train_dataset)

print('Train Loss:', train_loss)
print('Train Accuracy:', train_acc)
print('Train Recall:', train_recall)
print('Train Precision:', train_precision)

test_loss, test_acc, test_recall, test_precision = doubleRNNModel.evaluate(test_dataset)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Test Recall:', test_recall)
print('Test Precision:', test_precision)


validate_loss, validate_acc, validate_recall, validate_precision = doubleRNNModel.evaluate(validate_dataset)

print('Validate Loss:', validate_loss)
print('Validate Accuracy:', validate_acc)
print('Validate Recall:', validate_recall)
print('Validate Precision:', validate_precision)
# Out:
# Single LSTM Model
# 270/270 [==============================] - 4s 16ms/step - loss: 0.2795 - accuracy: 0.8796 - recall: 0.6957 - precision: 0.8482
# Train Loss: 0.2795301675796509
# Train Accuracy: 0.8796296119689941
# Train Recall: 0.6956701278686523
# Train Precision: 0.8481649160385132
# 68/68 [==============================] - 1s 16ms/step - loss: 0.3442 - accuracy: 0.8588 - recall: 0.6505 - precision: 0.8199
# Test Loss: 0.3441510796546936
# Test Accuracy: 0.8588289618492126
# Test Recall: 0.6505246162414551
# Test Precision: 0.8199389576911926
# 44/44 [==============================] - 1s 15ms/step - loss: 0.3581 - accuracy: 0.8511 - recall: 0.6110 - precision: 0.7526
# Validate Loss: 0.358093798160553
# Validate Accuracy: 0.8510714173316956
# Validate Recall: 0.6110325455665588
# Validate Precision: 0.7526132464408875
#
# SimpleRNN Model
# 270/270 [==============================] - 1s 5ms/step - loss: 0.2417 - accuracy: 0.9054 - recall_1: 0.7713 - precision_1: 0.8769
# Train Loss: 0.2417227327823639
# Train Accuracy: 0.9054397940635681
# Train Recall: 0.7713401913642883
# Train Precision: 0.8769338726997375
# 68/68 [==============================] - 0s 5ms/step - loss: 0.3632 - accuracy: 0.8523 - recall_1: 0.6626 - precision_1: 0.7887
# Test Loss: 0.3632405698299408
# Test Accuracy: 0.8523489832878113
# Test Recall: 0.6626311540603638
# Test Precision: 0.7886647582054138
# 44/44 [==============================] - 0s 5ms/step - loss: 0.4074 - accuracy: 0.8346 - recall_1: 0.6082 - precision_1: 0.6981
# Validate Loss: 0.4074231684207916
# Validate Accuracy: 0.8346428275108337
# Validate Recall: 0.608203649520874
# Validate Precision: 0.698051929473877
#
# DoubleLSTM Model
# 270/270 [==============================] - 8s 30ms/step - loss: 0.3140 - accuracy: 0.8701 - recall_2: 0.6961 - precision_2: 0.8143
# Train Loss: 0.3139585256576538
# Train Accuracy: 0.8701388835906982
# Train Recall: 0.6960824728012085
# Train Precision: 0.8142788410186768
# 68/68 [==============================] - 2s 28ms/step - loss: 0.4767 - accuracy: 0.8533 - recall_2: 0.6578 - precision_2: 0.7951
# Test Loss: 0.4766691029071808
# Test Accuracy: 0.8532747030258179
# Test Recall: 0.6577885150909424
# Test Precision: 0.795121967792511
# 44/44 [==============================] - 1s 27ms/step - loss: 0.4733 - accuracy: 0.8446 - recall_2: 0.6124 - precision_2: 0.7290
# Validate Loss: 0.47333604097366333
# Validate Accuracy: 0.8446428775787354
# Validate Recall: 0.6124469637870789
# Validate Precision: 0.7289562225341797

# %%
#Predict
no_example = df_validate["text_a"][0]
yes_example = df_validate["text_a"][6]

print("Single LSTM Prediction")
predictions = model.predict(np.array(df_validate["text_a"]))
#Poisitive if predictions >= 0

print(predictions[:20])

print("Simple RNN Prediction")
predictions = simpleRNNModel.predict(np.array(df_validate["text_a"]))
#Poisitive if predictions >= 0

print(predictions[:20])

print("Double LSTM Prediction")
predictions = doubleRNNModel.predict(np.array(df_validate["text_a"]))
#Poisitive if predictions >= 0

print(predictions[:20])
# Out:
# Single LSTM Prediction
# 88/88 [==============================] - 3s 8ms/step
# [[ -4.1540217]
#  [ -1.5017694]
#  [ -5.497215 ]
#  [ -2.5099046]
#  [ -1.1189702]
#  [  0.5589967]
#  [  1.6693711]
#  [ -5.0866833]
#  [-10.306117 ]
#  [ -0.6067909]
#  [ -3.4582903]
#  [ -2.0887394]
#  [  1.5291438]
#  [ -3.3506222]
#  [  3.5821571]
#  [  0.1484188]
#  [  2.1730726]
#  [ -2.6216085]
#  [  3.199164 ]
#  [ -4.7999473]]
# Simple RNN Prediction
# 88/88 [==============================] - 0s 3ms/step
# [[-4.088314  ]
#  [-1.2394911 ]
#  [-4.5168633 ]
#  [-1.9821457 ]
#  [-2.5142229 ]
#  [-0.5067939 ]
#  [-0.42692828]
#  [-4.256771  ]
#  [-7.106757  ]
#  [-1.359857  ]
#  [-2.9053571 ]
#  [-2.2489903 ]
#  [ 1.157086  ]
#  [-3.0331047 ]
#  [ 3.4147785 ]
#  [ 1.31064   ]
#  [ 0.7280008 ]
#  [-1.543102  ]
#  [ 1.3637115 ]
#  [-5.1051793 ]]
# Double LSTM Prediction
# 88/88 [==============================] - 5s 11ms/step
# [[-8.7191984e-03]
#  [ 9.9723719e-02]
#  [-3.9113410e-02]
#  [ 7.6477639e-02]
#  [ 3.8544154e-01]
#  [ 5.4287869e-01]
#  [ 6.2544757e-01]
#  [-9.7266072e-04]
#  [-6.6218868e-02]
#  [ 3.8161048e-01]
#  [ 1.9966969e-02]
#  [ 1.6139531e-01]
#  [ 5.7089913e-01]
#  [ 1.6613273e-02]
#  [ 1.6228894e+00]
#  [ 3.7962061e-01]
#  [ 1.0808331e+00]
#  [-2.6413120e-02]
#  [ 1.5785375e+00]
#  [-8.3600283e-03]]

# %%
# Single LSTM Model

plt.figure(figsize=(8, 8))
plt.subplot(2, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(0, 1)
plt.subplot(2, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)
plt.subplot(2, 2, 3)
plot_graphs(history, 'precision')
plt.ylim(0, 1)
plt.subplot(2, 2, 4)
plot_graphs(history, 'recall')
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# Simple RNN Model

plt.figure(figsize=(8, 8))
plt.subplot(2, 2, 1)
plot_graphs(simpleRNNHistory, 'accuracy')
plt.ylim(0, 1)
plt.subplot(2, 2, 2)
plot_graphs(simpleRNNHistory, 'loss')
plt.ylim(0, None)
plt.subplot(2, 2, 3)
plot_graphs(simpleRNNHistory, 'precision_1')
plt.ylim(0, 1)
plt.subplot(2, 2, 4)
plot_graphs(simpleRNNHistory, 'recall_1')
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# Single Double LSTM Model

plt.figure(figsize=(8, 8))
plt.subplot(2, 2, 1)
plot_graphs(doubleRNNHistory, 'accuracy')
plt.ylim(0, 1)
plt.subplot(2, 2, 2)
plot_graphs(doubleRNNHistory, 'loss')
plt.ylim(0, None)
plt.subplot(2, 2, 3)
plot_graphs(doubleRNNHistory, 'precision_2')
plt.ylim(0, 1)
plt.subplot(2, 2, 4)
plot_graphs(doubleRNNHistory, 'recall_2')
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)
